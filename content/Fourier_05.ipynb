# %% [markdown]
# You can save your work offline (without risk of loss of data) by using `File->Download`. Later you can upload your creationg back to the online environment using the "upload" button ![image.png](attachment:9af029fd-4903-4ebf-87d6-5c31c2365f07.png)

# %% [markdown]
# ## Setup

# %%
# SETUP CELL
# %pip -q install numpy sympy matplotlib ipywidgets pandas plotly anywidget scipy
import src_path
from gu_toolkit import *
from helpers.Fourier_01_helper import *

# %%
display(play(sin(2*pi*220*x**2),(x,0,10)))

# %%
display(play(
    sin(2*pi*220*(x+0.5*sin(x))),(x,0,10)))

# %%
expr1=0
base_freq=220
for k in np.arange(-11,11+0.1,):
    #print(k)
    #    expr1=expr1+exp(-1*abs(k/2+x/10-floor(x/10) ))*sin(2*pi * base_freq*10* exp(log(2)*(k/2+x/10 -floor(x/10))))
    expr1=expr1+exp(-1*abs(k/2+x/10 ))*sin(2*pi * base_freq*10* exp(log(2)*(k/2+x/10 )))
display(expr1)
display(play(expr1,(x,0,60)))
